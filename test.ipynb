# %%
import datetime
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
api_url = "https://ftx.com/api"
api= "/markets"
url = api_url + api
url
# Out:
# 'https://ftx.com/api/markets'

# %%
markets= requests.get(url).json()
data = markets["result"]
data
# Out:
# [{'name': '1INCH-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.6395,
#   'bid': 0.6398,
#   'ask': 0.6399,
#   'price': 0.6398,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.003271537622682661,
#   'change24h': 0.017655479560998888,
#   'changeBod': 0.02630734680782804,
#   'quoteVolume24h': 4511918.364,
#   'volumeUsd24h': 4511918.364,
#   'priceHigh24h': 0.6485,
#   'priceLow24h': 0.6163},
#  {'name': '1INCH-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.6319,
#   'bid': 0.6343,
#   'ask': 0.6373,
#   'price': 0.6343,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.00782105427811669,
#   'change24h': 0.016832318050657262,
#   'changeBod': 0.023229553153734473,
#   'quoteVolume24h': 9354.948,
#   'volumeUsd24h': 9354.948,
#   'priceHigh24h': 0.6448,
#   'priceLow24h': 0.6131},
#  {'name': '1INCH-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.6234,
#   'bid': 0.6174,
#   'ask': 0.6203,
#   'price': 0.6203,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': '1INCH',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.002733118971061093,
#   'change24h': 0.01571966595709841,
#   'changeBod': 0.025797916322143212,
#   'quoteVolume24h': 327.167,
#   'volumeUsd24h': 327.167,
#   'priceHigh24h': 0.6258,
#   'priceLow24h': 0.5976},
#  {'name': '1INCH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.6389,
#   'bid': 0.6395,
#   'ask': 0.6399,
#   'price': 0.6395,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': '1INCH',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.003273067331670823,
#   'change24h': 0.016531553012239707,
#   'changeBod': 0.024839743589743588,
#   'quoteVolume24h': 1158470.981,
#   'volumeUsd24h': 1158470.981,
#   'priceHigh24h': 0.6482,
#   'priceLow24h': 0.6165},
#  {'name': 'AAPL-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 153.23,
#   'bid': 151.62,
#   'ask': 151.73,
#   'price': 151.73,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAPL',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.00953064821463542,
#   'change24h': -0.002235812454790557,
#   'changeBod': 0.003040920208897997,
#   'quoteVolume24h': 17383.252,
#   'volumeUsd24h': 17383.252,
#   'priceHigh24h': 154.69,
#   'priceLow24h': 150.32},
#  {'name': 'AAPL-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 151.5,
#   'bid': 151.5,
#   'ask': 151.62,
#   'price': 151.5,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAPL',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.008961863020867404,
#   'change24h': -0.0013183915622940012,
#   'changeBod': 0.0025145579671784013,
#   'quoteVolume24h': 100833.2938,
#   'volumeUsd24h': 100833.2938,
#   'priceHigh24h': 154.58,
#   'priceLow24h': 150.0},
#  {'name': 'AAPL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 151.46,
#   'bid': 151.67,
#   'ask': 151.89,
#   'price': 151.67,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.009793040412613436,
#   'change24h': -0.0021710526315789473,
#   'changeBod': 0.0028431631843427664,
#   'quoteVolume24h': 28457.6169,
#   'volumeUsd24h': 28457.6169,
#   'priceHigh24h': 154.71,
#   'priceLow24h': 150.35},
#  {'name': 'AAVE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 78.66,
#   'bid': 78.64,
#   'ask': 78.66,
#   'price': 78.66,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.00832072617246596,
#   'change24h': 0.03745713532049591,
#   'changeBod': 0.0329612606697308,
#   'quoteVolume24h': 12735652.0922,
#   'volumeUsd24h': 12735652.0922,
#   'priceHigh24h': 80.98,
#   'priceLow24h': 74.8},
#  {'name': 'AAVE-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 79.31,
#   'bid': 78.46,
#   'ask': 79.09,
#   'price': 79.09,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.0027739251040221915,
#   'change24h': 0.036837965390665965,
#   'changeBod': 0.039290407358738504,
#   'quoteVolume24h': 3821.9904,
#   'volumeUsd24h': 3821.9904,
#   'priceHigh24h': 80.83,
#   'priceLow24h': 75.24},
#  {'name': 'AAVE-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 79.5,
#   'bid': 77.57,
#   'ask': 78.38,
#   'price': 78.38,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AAVE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.008851795649974709,
#   'change24h': 0.035129424194400426,
#   'changeBod': 0.03828321632004239,
#   'quoteVolume24h': 3074.4354,
#   'volumeUsd24h': 3074.4354,
#   'priceHigh24h': 80.16,
#   'priceLow24h': 74.7},
#  {'name': 'AAVE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 78.69,
#   'bid': 78.63,
#   'ask': 78.7,
#   'price': 78.69,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.00794251134644478,
#   'change24h': 0.03771594355795859,
#   'changeBod': 0.03389830508474576,
#   'quoteVolume24h': 1552796.1961,
#   'volumeUsd24h': 1552796.1961,
#   'priceHigh24h': 81.01,
#   'priceLow24h': 74.82},
#  {'name': 'AAVE/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 78.78,
#   'bid': 78.53,
#   'ask': 78.75,
#   'price': 78.75,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AAVE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.007686491935483871,
#   'change24h': 0.03782287822878229,
#   'changeBod': 0.03387160299330445,
#   'quoteVolume24h': 54578.032,
#   'volumeUsd24h': 54572.5741968,
#   'priceHigh24h': 81.0,
#   'priceLow24h': 74.87},
#  {'name': 'ABNB-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 105.18,
#   'bid': 105.695,
#   'ask': 105.89,
#   'price': 105.695,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ABNB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.015921046506214794,
#   'change24h': 0.014104101703046294,
#   'changeBod': 0.016151516608181513,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 108.3,
#   'priceLow24h': 103.525},
#  {'name': 'ABNB-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 110.24,
#   'bid': 105.71,
#   'ask': 105.92,
#   'price': 105.92,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ABNB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01839581113016079,
#   'change24h': 0.016067916926471294,
#   'changeBod': 0.018559476872776228,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 109.0,
#   'priceLow24h': 103.415},
#  {'name': 'ABNB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.025,
#   'minProvideSize': 0.025,
#   'last': 106.535,
#   'bid': 105.375,
#   'ask': 105.995,
#   'price': 105.995,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ABNB',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.013265686091975424,
#   'change24h': 0.02031092072965298,
#   'changeBod': 0.020900553816518178,
#   'quoteVolume24h': 131.912625,
#   'volumeUsd24h': 131.912625,
#   'priceHigh24h': 108.22,
#   'priceLow24h': 103.455},
#  {'name': 'ACB-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.216,
#   'bid': 1.206,
#   'ask': 1.214,
#   'price': 1.214,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ACB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01620745542949757,
#   'change24h': 0.02533783783783784,
#   'changeBod': 0.037606837606837605,
#   'quoteVolume24h': 6366.4295,
#   'volumeUsd24h': 6366.4295,
#   'priceHigh24h': 1.237,
#   'priceLow24h': 1.163},
#  {'name': 'ACB-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.25,
#   'bid': 1.207,
#   'ask': 1.214,
#   'price': 1.214,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ACB',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01620745542949757,
#   'change24h': 0.021885521885521887,
#   'changeBod': -0.01700404858299595,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1.25,
#   'priceLow24h': 1.163},
#  {'name': 'ACB/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.244,
#   'bid': 1.208,
#   'ask': 1.214,
#   'price': 1.214,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ACB',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.01620745542949757,
#   'change24h': 0.02533783783783784,
#   'changeBod': 0.037606837606837605,
#   'quoteVolume24h': 582.3305,
#   'volumeUsd24h': 582.3305,
#   'priceHigh24h': 1.244,
#   'priceLow24h': 1.16},
#  {'name': 'ADA-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.45328,
#   'bid': 0.45335,
#   'ask': 0.4534,
#   'price': 0.45335,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': -0.006465044926583388,
#   'change24h': 0.019267952695714734,
#   'changeBod': 0.014750649118094726,
#   'quoteVolume24h': 34577939.06391,
#   'volumeUsd24h': 34577939.06391,
#   'priceHigh24h': 0.4633,
#   'priceLow24h': 0.44236},
#  {'name': 'ADA-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.450995,
#   'bid': 0.451765,
#   'ask': 0.452315,
#   'price': 0.451765,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': -0.006771537556750102,
#   'change24h': 0.017465822841827888,
#   'changeBod': 0.014244982263930672,
#   'quoteVolume24h': 684268.545545,
#   'volumeUsd24h': 684268.545545,
#   'priceHigh24h': 0.46191,
#   'priceLow24h': 0.44137},
#  {'name': 'ADA-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.44411,
#   'bid': 0.44411,
#   'ask': 0.445155,
#   'price': 0.44411,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ADA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': -0.00627636127675285,
#   'change24h': 0.021400397879509207,
#   'changeBod': 0.016014275582805243,
#   'quoteVolume24h': 22281.028045,
#   'volumeUsd24h': 22281.028045,
#   'priceHigh24h': 0.45239,
#   'priceLow24h': 0.433735},
#  {'name': 'AGLD-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.3285,
#   'bid': 0.328,
#   'ask': 0.329,
#   'price': 0.3285,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AGLD',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.00904977375565611,
#   'change24h': 0.02177293934681182,
#   'changeBod': 0.007668711656441718,
#   'quoteVolume24h': 1425462.69885,
#   'volumeUsd24h': 1425462.69885,
#   'priceHigh24h': 0.338,
#   'priceLow24h': 0.318},
#  {'name': 'AGLD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.3285,
#   'bid': 0.328,
#   'ask': 0.3295,
#   'price': 0.3285,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AGLD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.012030075187969926,
#   'change24h': 0.0249609984399376,
#   'changeBod': 0.006125574272588055,
#   'quoteVolume24h': 11597.8598,
#   'volumeUsd24h': 11597.8598,
#   'priceHigh24h': 0.3415,
#   'priceLow24h': 0.3185},
#  {'name': 'AKRO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.004,
#   'bid': 0.004,
#   'ask': 0.004005,
#   'price': 0.004,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AKRO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.018404907975460124,
#   'change24h': 0.008827238335435058,
#   'changeBod': 0.0,
#   'quoteVolume24h': 1887.97277,
#   'volumeUsd24h': 1887.97277,
#   'priceHigh24h': 0.00411,
#   'priceLow24h': 0.00396},
#  {'name': 'AKRO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-06,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.004,
#   'bid': 0.004,
#   'ask': 0.004015,
#   'price': 0.004,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AKRO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.022004889975550123,
#   'change24h': 0.010101010101010102,
#   'changeBod': 0.0037641154328732747,
#   'quoteVolume24h': 907.91716,
#   'volumeUsd24h': 907.826368284,
#   'priceHigh24h': 0.00409,
#   'priceLow24h': 0.00396},
#  {'name': 'ALCX-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 20.5,
#   'bid': 20.5,
#   'ask': 20.6,
#   'price': 20.5,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALCX',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.014423076923076924,
#   'change24h': 0.01485148514851485,
#   'changeBod': 0.01485148514851485,
#   'quoteVolume24h': 344351.9698,
#   'volumeUsd24h': 344351.9698,
#   'priceHigh24h': 21.9,
#   'priceLow24h': 20.0},
#  {'name': 'ALCX/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 20.7,
#   'bid': 20.5,
#   'ask': 20.6,
#   'price': 20.6,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALCX',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.009615384615384616,
#   'change24h': 0.019801980198019802,
#   'changeBod': 0.019801980198019802,
#   'quoteVolume24h': 23988.3427,
#   'volumeUsd24h': 23988.3427,
#   'priceHigh24h': 21.9,
#   'priceLow24h': 20.1},
#  {'name': 'ALEPH/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.11735,
#   'bid': 0.1173,
#   'ask': 0.1176,
#   'price': 0.11735,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALEPH',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.005086901229334464,
#   'change24h': -0.008868243243243243,
#   'changeBod': -0.003397027600849257,
#   'quoteVolume24h': 17399.15345,
#   'volumeUsd24h': 17399.15345,
#   'priceHigh24h': 0.1198,
#   'priceLow24h': 0.1165},
#  {'name': 'ALGO-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3669,
#   'bid': 0.3669,
#   'ask': 0.367,
#   'price': 0.3669,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.004612045577862181,
#   'change24h': 0.007690195001373249,
#   'changeBod': 0.0013646288209606986,
#   'quoteVolume24h': 21957381.5341,
#   'volumeUsd24h': 21957381.5341,
#   'priceHigh24h': 0.3753,
#   'priceLow24h': 0.3549},
#  {'name': 'ALGO-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3685,
#   'bid': 0.3664,
#   'ask': 0.368,
#   'price': 0.368,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.0040595399188092015,
#   'change24h': 0.006564551422319475,
#   'changeBod': 0.0013605442176870747,
#   'quoteVolume24h': 32387.7191,
#   'volumeUsd24h': 32387.7191,
#   'priceHigh24h': 0.3757,
#   'priceLow24h': 0.3582},
#  {'name': 'ALGO-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.369,
#   'bid': 0.3675,
#   'ask': 0.3703,
#   'price': 0.369,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALGO',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 1200.0,
#   'change1h': -0.0083310937919914,
#   'change24h': 0.0021727322107550242,
#   'changeBod': 0.004628369180506398,
#   'quoteVolume24h': 28530.5978,
#   'volumeUsd24h': 28530.5978,
#   'priceHigh24h': 0.3788,
#   'priceLow24h': 0.3603},
#  {'name': 'ALGO/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.3666,
#   'bid': 0.3666,
#   'ask': 0.3669,
#   'price': 0.3666,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 960.0,
#   'change1h': -0.00596529284164859,
#   'change24h': 0.0060373216245883645,
#   'changeBod': 0.0,
#   'quoteVolume24h': 541466.6982,
#   'volumeUsd24h': 541466.6982,
#   'priceHigh24h': 0.3752,
#   'priceLow24h': 0.3567},
#  {'name': 'ALGO/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.367,
#   'bid': 0.3664,
#   'ask': 0.3671,
#   'price': 0.367,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALGO',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 672.0,
#   'change1h': -0.005420054200542005,
#   'change24h': 0.007411474059840791,
#   'changeBod': 0.0008181074447777475,
#   'quoteVolume24h': 31579.2711,
#   'volumeUsd24h': 31576.11317289,
#   'priceHigh24h': 0.3749,
#   'priceLow24h': 0.3573},
#  {'name': 'ALICE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.7525,
#   'bid': 1.7525,
#   'ask': 1.755,
#   'price': 1.7525,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALICE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.005673758865248227,
#   'change24h': 0.03240058910162003,
#   'changeBod': 0.021865889212827987,
#   'quoteVolume24h': 1104209.70975,
#   'volumeUsd24h': 1104209.70975,
#   'priceHigh24h': 1.7875,
#   'priceLow24h': 1.6725},
#  {'name': 'ALICE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 1.75,
#   'bid': 1.75,
#   'ask': 1.755,
#   'price': 1.75,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALICE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0084985835694051,
#   'change24h': 0.033973412112259974,
#   'changeBod': 0.021897810218978103,
#   'quoteVolume24h': 6694.46375,
#   'volumeUsd24h': 6694.46375,
#   'priceHigh24h': 1.785,
#   'priceLow24h': 1.675},
#  {'name': 'ALPHA-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.1099,
#   'bid': 0.10985,
#   'ask': 0.11,
#   'price': 0.1099,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALPHA',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.006329113924050633,
#   'change24h': 0.04220009483167378,
#   'changeBod': 0.047664442326024785,
#   'quoteVolume24h': 1108621.10615,
#   'volumeUsd24h': 1108621.10615,
#   'priceHigh24h': 0.112,
#   'priceLow24h': 0.1037},
#  {'name': 'ALPHA/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-05,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 0.10995,
#   'bid': 0.1098,
#   'ask': 0.10995,
#   'price': 0.10995,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ALPHA',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0063262539539087215,
#   'change24h': 0.041193181818181816,
#   'changeBod': 0.048141086749285036,
#   'quoteVolume24h': 240174.9633,
#   'volumeUsd24h': 240174.9633,
#   'priceHigh24h': 0.11195,
#   'priceLow24h': 0.10395},
#  {'name': 'ALT-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1896.2,
#   'bid': 1895.0,
#   'ask': 1896.1,
#   'price': 1896.1,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': -0.008834291688447465,
#   'change24h': 0.02141298785250626,
#   'changeBod': 0.017630484368710585,
#   'quoteVolume24h': 3044687.65405,
#   'volumeUsd24h': 3044687.65405,
#   'priceHigh24h': 1932.15,
#   'priceLow24h': 1840.35},
#  {'name': 'ALT-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1889.65,
#   'bid': 1889.55,
#   'ask': 1893.45,
#   'price': 1889.65,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': -0.010861599664991626,
#   'change24h': 0.022869979430551045,
#   'changeBod': 0.016979710456918356,
#   'quoteVolume24h': 27211.1451,
#   'volumeUsd24h': 27211.1451,
#   'priceHigh24h': 1931.7,
#   'priceLow24h': 1837.85},
#  {'name': 'ALT-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.05,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 1858.2,
#   'bid': 1862.1,
#   'ask': 1865.4,
#   'price': 1862.1,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ALT',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 600.0,
#   'change1h': -0.009046884146665957,
#   'change24h': 0.023103760885689953,
#   'changeBod': 0.017874713020662514,
#   'quoteVolume24h': 5203.72375,
#   'volumeUsd24h': 5203.72375,
#   'priceHigh24h': 1897.25,
#   'priceLow24h': 1808.6},
#  {'name': 'AMC-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 13.4675,
#   'bid': 13.03,
#   'ask': 13.36,
#   'price': 13.36,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMC',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.007541478129713424,
#   'change24h': -0.020527859237536656,
#   'changeBod': 0.04784313725490196,
#   'quoteVolume24h': 17603.0075,
#   'volumeUsd24h': 17603.0075,
#   'priceHigh24h': 13.745,
#   'priceLow24h': 12.71},
#  {'name': 'AMC-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.3375,
#   'bid': 7.1275,
#   'ask': 7.1775,
#   'price': 7.1775,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMC',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.024464831804281346,
#   'change24h': -0.03657718120805369,
#   'changeBod': 0.03347732181425486,
#   'quoteVolume24h': 2908.5865,
#   'volumeUsd24h': 2908.5865,
#   'priceHigh24h': 7.5,
#   'priceLow24h': 6.885},
#  {'name': 'AMC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 7.535,
#   'bid': 7.1275,
#   'ask': 7.1825,
#   'price': 7.1825,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMC',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.031355360755225894,
#   'change24h': -0.03622945320362295,
#   'changeBod': 0.02974910394265233,
#   'quoteVolume24h': 10721.616,
#   'volumeUsd24h': 10721.616,
#   'priceHigh24h': 7.535,
#   'priceLow24h': 6.8775},
#  {'name': 'AMD-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 66.75,
#   'bid': 67.13,
#   'ask': 67.22,
#   'price': 67.13,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMD',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01583345550505791,
#   'change24h': -0.0014874312063067083,
#   'changeBod': 0.00403828896201017,
#   'quoteVolume24h': 4026.0493,
#   'volumeUsd24h': 4026.0493,
#   'priceHigh24h': 68.85,
#   'priceLow24h': 66.34},
#  {'name': 'AMD-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 67.5,
#   'bid': 67.14,
#   'ask': 67.25,
#   'price': 67.25,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMD',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.011320199941193767,
#   'change24h': 0.00029748624126134165,
#   'changeBod': 0.006435199042202933,
#   'quoteVolume24h': 7376.32,
#   'volumeUsd24h': 7376.32,
#   'priceHigh24h': 68.88,
#   'priceLow24h': 66.33},
#  {'name': 'AMD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 68.15,
#   'bid': 67.05,
#   'ask': 67.21,
#   'price': 67.21,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.013793103448275862,
#   'change24h': 0.002685364762046845,
#   'changeBod': 0.012503766194636938,
#   'quoteVolume24h': 5428.6428,
#   'volumeUsd24h': 5428.6428,
#   'priceHigh24h': 68.81,
#   'priceLow24h': 65.96},
#  {'name': 'AMPL-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 1.1288,
#   'bid': 1.1288,
#   'ask': 1.1309,
#   'price': 1.1288,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMPL',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.012768934755990904,
#   'change24h': -0.03595524809975233,
#   'changeBod': -0.02538421688827491,
#   'quoteVolume24h': 278573.021,
#   'volumeUsd24h': 278573.021,
#   'priceHigh24h': 1.1854,
#   'priceLow24h': 1.1148},
#  {'name': 'AMPL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1263,
#   'bid': 1.1263,
#   'ask': 1.1297,
#   'price': 1.1263,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.01132373595505618,
#   'change24h': -0.04388794567062818,
#   'changeBod': -0.036609357625523906,
#   'quoteVolume24h': 183951.3725,
#   'volumeUsd24h': 183951.3725,
#   'priceHigh24h': 1.1974,
#   'priceLow24h': 1.1255},
#  {'name': 'AMPL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0001,
#   'sizeIncrement': 1.0,
#   'minProvideSize': 1.0,
#   'last': 1.1264,
#   'bid': 1.1264,
#   'ask': 1.1293,
#   'price': 1.1264,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMPL',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.008276104948054235,
#   'change24h': -0.03997272649791187,
#   'changeBod': -0.03371364845157416,
#   'quoteVolume24h': 32046.7827,
#   'volumeUsd24h': 32043.57802173,
#   'priceHigh24h': 1.1935,
#   'priceLow24h': 1.1264},
#  {'name': 'AMZN-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 116.7,
#   'bid': 114.0,
#   'ask': 114.3,
#   'price': 114.3,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMZN',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01124567474048443,
#   'change24h': -0.012100259291270527,
#   'changeBod': -0.009532062391681109,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 117.7,
#   'priceLow24h': 114.0},
#  {'name': 'AMZN-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 113.9,
#   'bid': 114.0,
#   'ask': 114.3,
#   'price': 114.0,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AMZN',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.010416666666666666,
#   'change24h': -0.011274934952298352,
#   'changeBod': -0.006102877070619006,
#   'quoteVolume24h': 663.1076,
#   'volumeUsd24h': 663.1076,
#   'priceHigh24h': 117.6,
#   'priceLow24h': 113.4},
#  {'name': 'AMZN/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.1,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 114.0,
#   'bid': 114.1,
#   'ask': 114.2,
#   'price': 114.1,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'AMZN',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.011265164644714038,
#   'change24h': -0.012975778546712802,
#   'changeBod': -0.006962576153176675,
#   'quoteVolume24h': 35497.6532,
#   'volumeUsd24h': 35497.6532,
#   'priceHigh24h': 117.9,
#   'priceLow24h': 114.0},
#  {'name': 'APE-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.589,
#   'bid': 5.589,
#   'ask': 5.5905,
#   'price': 5.589,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01809557273366128,
#   'change24h': 0.022689844464775847,
#   'changeBod': 0.016274206746067825,
#   'quoteVolume24h': 33776147.0337,
#   'volumeUsd24h': 33776147.0337,
#   'priceHigh24h': 5.797,
#   'priceLow24h': 5.4035},
#  {'name': 'APE-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.6185,
#   'bid': 5.58,
#   'ask': 5.589,
#   'price': 5.589,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01809557273366128,
#   'change24h': 0.02287701317715959,
#   'changeBod': 0.01979746373506067,
#   'quoteVolume24h': 3514.5136,
#   'volumeUsd24h': 3514.5136,
#   'priceHigh24h': 5.781,
#   'priceLow24h': 5.409},
#  {'name': 'APE-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.484,
#   'bid': 5.455,
#   'ask': 5.468,
#   'price': 5.468,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'APE',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01840050264787721,
#   'change24h': 0.026468931856579687,
#   'changeBod': 0.018534041166061284,
#   'quoteVolume24h': 2677.8732,
#   'volumeUsd24h': 2677.8732,
#   'priceHigh24h': 5.6465,
#   'priceLow24h': 5.29},
#  {'name': 'APE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 5.59,
#   'bid': 5.587,
#   'ask': 5.59,
#   'price': 5.59,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APE',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.018006148440931048,
#   'change24h': 0.02203126428375537,
#   'changeBod': 0.01673335758457621,
#   'quoteVolume24h': 4291590.743,
#   'volumeUsd24h': 4291590.743,
#   'priceHigh24h': 5.797,
#   'priceLow24h': 5.406},
#  {'name': 'APEAMC/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 3.5175,
#   'bid': 3.4075,
#   'ask': 3.43,
#   'price': 3.43,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APEAMC',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.04055944055944056,
#   'change24h': -0.09498680738786279,
#   'changeBod': -0.04256803907885555,
#   'quoteVolume24h': 917.002,
#   'volumeUsd24h': 917.002,
#   'priceHigh24h': 3.9375,
#   'priceLow24h': 3.3575},
#  {'name': 'APHA/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 2.417,
#   'bid': 2.312,
#   'ask': 2.316,
#   'price': 2.316,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'APHA',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.028115820394460762,
#   'change24h': 0.007394519356241845,
#   'changeBod': 0.018469656992084433,
#   'quoteVolume24h': 3.6255,
#   'volumeUsd24h': 3.6255,
#   'priceHigh24h': 2.419,
#   'priceLow24h': 2.262},
#  {'name': 'AR-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.001,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 9.785,
#   'bid': 9.781,
#   'ask': 9.786,
#   'price': 9.785,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'AR',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.016582914572864323,
#   'change24h': 0.034902168164992066,
#   'changeBod': 0.03753578623687838,
#   'quoteVolume24h': 2143968.1671,
#   'volumeUsd24h': 2143968.1671,
#   'priceHigh24h': 10.106,
#   'priceLow24h': 9.295},
#  {'name': 'ARKK-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 38.87,
#   'bid': 38.2,
#   'ask': 38.25,
#   'price': 38.25,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ARKK',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01595060457936712,
#   'change24h': 0.009501187648456057,
#   'changeBod': 0.017287234042553192,
#   'quoteVolume24h': 59711.3919,
#   'volumeUsd24h': 59711.3919,
#   'priceHigh24h': 39.33,
#   'priceLow24h': 37.46},
#  {'name': 'ARKK-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 38.92,
#   'bid': 38.22,
#   'ask': 38.31,
#   'price': 38.31,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ARKK',
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.01567317574511819,
#   'change24h': 0.011618695537364668,
#   'changeBod': 0.017800212539851222,
#   'quoteVolume24h': 34138.5435,
#   'volumeUsd24h': 34138.5435,
#   'priceHigh24h': 39.35,
#   'priceLow24h': 37.41},
#  {'name': 'ARKK/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.01,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 38.14,
#   'bid': 38.14,
#   'ask': 38.31,
#   'price': 38.14,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ARKK',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': True,
#   'tokenizedEquity': True,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.02104722792607803,
#   'change24h': 0.006067000791347929,
#   'changeBod': 0.010866684336072092,
#   'quoteVolume24h': 16757.7201,
#   'volumeUsd24h': 16757.7201,
#   'priceHigh24h': 39.32,
#   'priceLow24h': 37.42},
#  {'name': 'ASD-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.1065,
#   'bid': 0.10623,
#   'ask': 0.10646,
#   'price': 0.10646,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ASD',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': 0.0013167795334838223,
#   'change24h': 0.02840030911901082,
#   'changeBod': -0.0016879219804951237,
#   'quoteVolume24h': 188103.019698,
#   'volumeUsd24h': 188103.019698,
#   'priceHigh24h': 0.1088,
#   'priceLow24h': 0.10212},
#  {'name': 'ASD/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-05,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.10625,
#   'bid': 0.10626,
#   'ask': 0.10654,
#   'price': 0.10626,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ASD',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0003765769158350593,
#   'change24h': 0.028057275541795667,
#   'changeBod': -0.0033764772087788407,
#   'quoteVolume24h': 28553.601085,
#   'volumeUsd24h': 28553.601085,
#   'priceHigh24h': 0.10903,
#   'priceLow24h': 0.10229},
#  {'name': 'ATLAS-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.00455125,
#   'bid': 0.004547,
#   'ask': 0.0045515,
#   'price': 0.00455125,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATLAS',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 350.0,
#   'change1h': -0.0016451878256100905,
#   'change24h': 0.013754315625348035,
#   'changeBod': 0.006190239319073675,
#   'quoteVolume24h': 118737.071995,
#   'volumeUsd24h': 118737.071995,
#   'priceHigh24h': 0.0046255,
#   'priceLow24h': 0.00442225},
#  {'name': 'ATLAS/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-07,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.004553,
#   'bid': 0.00455275,
#   'ask': 0.004567,
#   'price': 0.004553,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATLAS',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0004939355688491302,
#   'change24h': 0.011665370514387291,
#   'changeBod': 0.004412089124200309,
#   'quoteVolume24h': 182015.067905,
#   'volumeUsd24h': 182015.067905,
#   'priceHigh24h': 0.0050685,
#   'priceLow24h': 0.004351},
#  {'name': 'ATOM-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 13.9325,
#   'bid': 13.9325,
#   'ask': 13.934,
#   'price': 13.9325,
#   'type': 'future',
#   'futureType': 'perpetual',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': -0.02597175615212528,
#   'change24h': -0.04029619424832099,
#   'changeBod': 0.008578253945272911,
#   'quoteVolume24h': 155765945.944295,
#   'volumeUsd24h': 155765945.944295,
#   'priceHigh24h': 14.738,
#   'priceLow24h': 13.7225},
#  {'name': 'ATOM-0930',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 13.88,
#   'bid': 13.871,
#   'ask': 13.9135,
#   'price': 13.88,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': -0.03004891684136967,
#   'change24h': -0.04325348957435809,
#   'changeBod': 0.005979344084073202,
#   'quoteVolume24h': 41735.659395,
#   'volumeUsd24h': 41735.659395,
#   'priceHigh24h': 14.68,
#   'priceLow24h': 13.727},
#  {'name': 'ATOM-1230',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.01,
#   'minProvideSize': 0.01,
#   'last': 13.5635,
#   'bid': 13.5,
#   'ask': 13.5595,
#   'price': 13.5595,
#   'type': 'future',
#   'futureType': 'future',
#   'baseCurrency': None,
#   'isEtfMarket': False,
#   'quoteCurrency': None,
#   'underlying': 'ATOM',
#   'restricted': False,
#   'highLeverageFeeExempt': False,
#   'largeOrderThreshold': 2500.0,
#   'change1h': -0.026177822464808962,
#   'change24h': -0.044129568926016,
#   'changeBod': 0.007841534116247956,
#   'quoteVolume24h': 622284.291565,
#   'volumeUsd24h': 622284.291565,
#   'priceHigh24h': 14.3325,
#   'priceLow24h': 13.375},
#  {'name': 'ATOM/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 13.94,
#   'bid': 13.9375,
#   'ask': 13.9425,
#   'price': 13.94,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATOM',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 2000.0,
#   'change1h': -0.02585604472396925,
#   'change24h': -0.03977957637334252,
#   'changeBod': 0.008500633025863628,
#   'quoteVolume24h': 12028350.904,
#   'volumeUsd24h': 12028350.904,
#   'priceHigh24h': 14.74,
#   'priceLow24h': 13.755},
#  {'name': 'ATOM/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0025,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 13.8975,
#   'bid': 13.925,
#   'ask': 13.9475,
#   'price': 13.925,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ATOM',
#   'isEtfMarket': False,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 1400.0,
#   'change1h': -0.02775353464828068,
#   'change24h': -0.04262633207287728,
#   'changeBod': 0.00668714982830291,
#   'quoteVolume24h': 584486.787,
#   'volumeUsd24h': 584428.3383213,
#   'priceHigh24h': 14.7325,
#   'priceLow24h': 13.76},
#  {'name': 'AUDIO-PERP',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.0005,
#   'sizeIncrement': 0.1,
#   'minProvideSize': 0.1,
#   'last': 0.2205,
#   'bid': 0.2205,
#   'ask': 0.221,
#   'price': 0.2205,
#   'type': 'future',
# ...
#   'priceHigh24h': 1.71e-06,
#   'priceLow24h': 1.39e-06},
#  {'name': 'VETBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 100000.0,
#   'minProvideSize': 100000.0,
#   'last': 1.42e-06,
#   'bid': 1.47e-06,
#   'ask': 1.5e-06,
#   'price': 1.47e-06,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.035211267605633804,
#   'change24h': -0.1301775147928994,
#   'changeBod': -0.11976047904191617,
#   'quoteVolume24h': 12.234,
#   'volumeUsd24h': 12.2327766,
#   'priceHigh24h': 1.75e-06,
#   'priceLow24h': 1.39e-06},
#  {'name': 'VETBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 9.357e-05,
#   'bid': 9.348e-05,
#   'ask': 9.439e-05,
#   'price': 9.357e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0327682447798222,
#   'change24h': 0.10134180790960452,
#   'changeBod': 0.1026396417629036,
#   'quoteVolume24h': 6281.31641,
#   'volumeUsd24h': 6281.31641,
#   'priceHigh24h': 9.922e-05,
#   'priceLow24h': 8.187e-05},
#  {'name': 'VETBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 9.306e-05,
#   'bid': 9.331e-05,
#   'ask': 9.466e-05,
#   'price': 9.331e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.033457634141288585,
#   'change24h': 0.09776470588235295,
#   'changeBod': 0.10282472520978608,
#   'quoteVolume24h': 8960.08834,
#   'volumeUsd24h': 8959.192331166,
#   'priceHigh24h': 0.00010078,
#   'priceLow24h': 8.23e-05},
#  {'name': 'VETHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 100.5,
#   'bid': 96.0,
#   'ask': 97.0,
#   'price': 97.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'VETHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.010416666666666666,
#   'change24h': -0.03482587064676617,
#   'changeBod': -0.03482587064676617,
#   'quoteVolume24h': 199.99902,
#   'volumeUsd24h': 199.99902,
#   'priceHigh24h': 101.0,
#   'priceLow24h': 95.0},
#  {'name': 'XAUTBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 5895.0,
#   'bid': 5770.0,
#   'ask': 5862.5,
#   'price': 5862.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.005574614065180103,
#   'change24h': 0.021341463414634148,
#   'changeBod': -0.003399915002124947,
#   'quoteVolume24h': 218.2275,
#   'volumeUsd24h': 218.2275,
#   'priceHigh24h': 5920.0,
#   'priceLow24h': 5712.5},
#  {'name': 'XAUTBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1.0,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 4565.0,
#   'bid': 4510.0,
#   'ask': 4596.0,
#   'price': 4565.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.0054466230936819175,
#   'changeBod': 0.016251113089937666,
#   'quoteVolume24h': 19.6597,
#   'volumeUsd24h': 19.6597,
#   'priceHigh24h': 4611.0,
#   'priceLow24h': 4447.0},
#  {'name': 'XAUTHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.25,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 5657.25,
#   'bid': 5612.5,
#   'ask': 5637.0,
#   'price': 5637.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.0007976601967561818,
#   'change24h': -0.0003546728143287817,
#   'changeBod': 0.002044262732201582,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 5657.25,
#   'priceLow24h': 5616.5},
#  {'name': 'XAUTHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 4926.5,
#   'bid': 4948.0,
#   'ask': 4984.0,
#   'price': 4948.0,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XAUTHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0019236610306773312,
#   'change24h': -0.0001010407194099222,
#   'changeBod': -0.0035243177927701138,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 4983.5,
#   'priceLow24h': 4926.5},
#  {'name': 'XLMBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 2.5e-06,
#   'sizeIncrement': 10.0,
#   'minProvideSize': 10.0,
#   'last': 0.0091175,
#   'bid': 0.008995,
#   'ask': 0.009135,
#   'price': 0.0091175,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XLMBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.019854586129753916,
#   'change24h': -0.015920129519697786,
#   'changeBod': 0.0,
#   'quoteVolume24h': 196.75565,
#   'volumeUsd24h': 196.75565,
#   'priceHigh24h': 0.009335,
#   'priceLow24h': 0.0084375},
#  {'name': 'XLMBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-07,
#   'sizeIncrement': 100.0,
#   'minProvideSize': 100.0,
#   'last': 0.002332,
#   'bid': 0.002332,
#   'ask': 0.002368,
#   'price': 0.002332,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XLMBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.032766486934881794,
#   'change24h': 0.0034423407917383822,
#   'changeBod': 0.006691128858191237,
#   'quoteVolume24h': 47869.5639,
#   'volumeUsd24h': 47869.5639,
#   'priceHigh24h': 0.002508,
#   'priceLow24h': 0.002275},
#  {'name': 'XRPBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000000.0,
#   'minProvideSize': 10000000.0,
#   'last': 5e-08,
#   'bid': 5e-08,
#   'ask': 7e-08,
#   'price': 5e-08,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.16666666666666666,
#   'changeBod': 0.0,
#   'quoteVolume24h': 11.07,
#   'volumeUsd24h': 11.07,
#   'priceHigh24h': 6e-08,
#   'priceLow24h': 5e-08},
#  {'name': 'XRPBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000000.0,
#   'minProvideSize': 10000000.0,
#   'last': 9e-08,
#   'bid': 5e-08,
#   'ask': 1.7e-07,
#   'price': 9e-08,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 9e-08,
#   'priceLow24h': 9e-08},
#  {'name': 'XRPBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 3.563e-05,
#   'bid': 3.532e-05,
#   'ask': 3.561e-05,
#   'price': 3.561e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.03364993215739484,
#   'change24h': -0.019548458149779735,
#   'changeBod': 0.0218077474892396,
#   'quoteVolume24h': 130296.74749,
#   'volumeUsd24h': 130296.74749,
#   'priceHigh24h': 3.955e-05,
#   'priceLow24h': 3.45e-05},
#  {'name': 'XRPBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 3.546e-05,
#   'bid': 3.527e-05,
#   'ask': 3.564e-05,
#   'price': 3.546e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.04291497975708502,
#   'change24h': -0.025556471558120363,
#   'changeBod': 0.016045845272206302,
#   'quoteVolume24h': 9582.42683,
#   'volumeUsd24h': 9581.468587317,
#   'priceHigh24h': 3.938e-05,
#   'priceLow24h': 3.468e-05},
#  {'name': 'XRPHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.5,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 13551.0,
#   'bid': 13105.0,
#   'ask': 13136.5,
#   'price': 13136.5,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.006278603578047581,
#   'change24h': -0.0023163970532391583,
#   'changeBod': 0.002939380058024126,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 13551.0,
#   'priceLow24h': 13077.0},
#  {'name': 'XRPHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 43.515,
#   'bid': 43.465,
#   'ask': 43.635,
#   'price': 43.515,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XRPHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.01457216134297039,
#   'change24h': 0.0,
#   'changeBod': -0.0051440329218107,
#   'quoteVolume24h': 3607.681925,
#   'volumeUsd24h': 3607.681925,
#   'priceHigh24h': 43.88,
#   'priceLow24h': 41.94},
#  {'name': 'XTZBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000000.0,
#   'minProvideSize': 1000000.0,
#   'last': 1.3e-07,
#   'bid': 1.2e-07,
#   'ask': 1.4e-07,
#   'price': 1.3e-07,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.0,
#   'change24h': -0.07142857142857142,
#   'changeBod': 0.0,
#   'quoteVolume24h': 75.88,
#   'volumeUsd24h': 75.88,
#   'priceHigh24h': 1.5e-07,
#   'priceLow24h': 1.2e-07},
#  {'name': 'XTZBEAR/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 1000000.0,
#   'minProvideSize': 1000000.0,
#   'last': 1.3e-07,
#   'bid': 1.2e-07,
#   'ask': 1.4e-07,
#   'price': 1.3e-07,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': 0.0,
#   'change24h': 0.0,
#   'changeBod': 0.0,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 1.3e-07,
#   'priceLow24h': 1.3e-07},
#  {'name': 'XTZBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 2.255e-05,
#   'bid': 2.027e-05,
#   'ask': 2.219e-05,
#   'price': 2.219e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.015964523281596452,
#   'change24h': 0.17407407407407408,
#   'changeBod': 0.09202755905511811,
#   'quoteVolume24h': 55.0816,
#   'volumeUsd24h': 55.0816,
#   'priceHigh24h': 2.352e-05,
#   'priceLow24h': 1.842e-05},
#  {'name': 'XTZBULL/USDT',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-08,
#   'sizeIncrement': 10000.0,
#   'minProvideSize': 10000.0,
#   'last': 2.042e-05,
#   'bid': 2.029e-05,
#   'ask': 2.221e-05,
#   'price': 2.042e-05,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USDT',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 196.0,
#   'change1h': -0.00825643516270034,
#   'change24h': -0.015903614457831325,
#   'changeBod': 0.0,
#   'quoteVolume24h': 20.4824,
#   'volumeUsd24h': 20.48035176,
#   'priceHigh24h': 2.168e-05,
#   'priceLow24h': 2.004e-05},
#  {'name': 'XTZHALF/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.25,
#   'sizeIncrement': 1e-05,
#   'minProvideSize': 1e-05,
#   'last': 6423.0,
#   'bid': 6317.0,
#   'ask': 6364.75,
#   'price': 6364.75,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZHALF',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.002781041911476694,
#   'change24h': 0.011964385086254869,
#   'changeBod': 0.011803513234242112,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 6423.0,
#   'priceLow24h': 6254.5},
#  {'name': 'XTZHEDGE/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 0.005,
#   'sizeIncrement': 0.001,
#   'minProvideSize': 0.001,
#   'last': 65.03,
#   'bid': 63.09,
#   'ask': 63.825,
#   'price': 63.825,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'XTZHEDGE',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.005593193634788089,
#   'change24h': -0.018529909272643395,
#   'changeBod': -0.018529909272643395,
#   'quoteVolume24h': 0.0,
#   'volumeUsd24h': 0.0,
#   'priceHigh24h': 65.42,
#   'priceLow24h': 62.22},
#  {'name': 'ZECBEAR/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 1e-06,
#   'sizeIncrement': 100.0,
#   'minProvideSize': 100.0,
#   'last': 0.002282,
#   'bid': 0.002479,
#   'ask': 0.002572,
#   'price': 0.002479,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ZECBEAR',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': 0.043789473684210524,
#   'change24h': -0.050918836140888206,
#   'changeBod': -0.06593820648078372,
#   'quoteVolume24h': 214.571,
#   'volumeUsd24h': 214.571,
#   'priceHigh24h': 0.002806,
#   'priceLow24h': 0.002277},
#  {'name': 'ZECBULL/USD',
#   'enabled': True,
#   'postOnly': False,
#   'priceIncrement': 5e-08,
#   'sizeIncrement': 1000.0,
#   'minProvideSize': 1000.0,
#   'last': 0.00018995,
#   'bid': 0.0001851,
#   'ask': 0.00018995,
#   'price': 0.00018995,
#   'type': 'spot',
#   'futureType': None,
#   'baseCurrency': 'ZECBULL',
#   'isEtfMarket': True,
#   'quoteCurrency': 'USD',
#   'underlying': None,
#   'restricted': False,
#   'highLeverageFeeExempt': True,
#   'largeOrderThreshold': 280.0,
#   'change1h': -0.036276002029426685,
#   'change24h': 0.06593714927048261,
#   'changeBod': 0.05851212036779047,
#   'quoteVolume24h': 464.3071,
#   'volumeUsd24h': 464.3071,
#   'priceHigh24h': 0.00020525,
#   'priceLow24h': 0.0001749}]

# %%
df=pd.DataFrame(data)
df
# Out:
#              name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 0      1INCH-PERP     True     False    1.000000e-04        1.00000
# 1      1INCH-0930     True     False    1.000000e-04        1.00000
# 2      1INCH-1230     True     False    1.000000e-04        1.00000
# 3       1INCH/USD     True     False    1.000000e-04        1.00000
# 4       AAPL-0930     True     False    1.000000e-02        0.01000
# ..            ...      ...       ...             ...            ...
# 930  XTZBULL/USDT     True     False    1.000000e-08    10000.00000
# 931   XTZHALF/USD     True     False    2.500000e-01        0.00001
# 932  XTZHEDGE/USD     True     False    5.000000e-03        0.00100
# 933   ZECBEAR/USD     True     False    1.000000e-06      100.00000
# 934   ZECBULL/USD     True     False    5.000000e-08     1000.00000
#
#      minProvideSize         last          bid          ask        price  ...  \
# 0           1.00000     0.639500     0.639800     0.639900     0.639800  ...
# 1           1.00000     0.631900     0.634300     0.637300     0.634300  ...
# 2           1.00000     0.623400     0.617400     0.620300     0.620300  ...
# 3           1.00000     0.638900     0.639500     0.639900     0.639500  ...
# 4           0.01000   153.230000   151.620000   151.730000   151.730000  ...
# ..              ...          ...          ...          ...          ...  ...
# 930     10000.00000     0.000020     0.000020     0.000022     0.000020  ...
# 931         0.00001  6423.000000  6317.000000  6364.750000  6364.750000  ...
# 932         0.00100    65.030000    63.090000    63.825000    63.825000  ...
# 933       100.00000     0.002282     0.002479     0.002572     0.002479  ...
# 934      1000.00000     0.000190     0.000185     0.000190     0.000190  ...
#
#     highLeverageFeeExempt largeOrderThreshold  change1h  change24h changeBod  \
# 0                   False               350.0 -0.003272   0.017655  0.026307
# 1                   False               350.0 -0.007821   0.016832  0.023230
# 2                   False               350.0 -0.002733   0.015720  0.025798
# 3                    True               280.0 -0.003273   0.016532  0.024840
# 4                   False               350.0 -0.009531  -0.002236  0.003041
# ..                    ...                 ...       ...        ...       ...
# 930                  True               196.0 -0.008256  -0.015904  0.000000
# 931                  True               280.0 -0.002781   0.011964  0.011804
# 932                  True               280.0  0.005593  -0.018530 -0.018530
# 933                  True               280.0  0.043789  -0.050919 -0.065938
# 934                  True               280.0 -0.036276   0.065937  0.058512
#
#     quoteVolume24h  volumeUsd24h  priceHigh24h  priceLow24h  tokenizedEquity
# 0     4.511918e+06  4.511918e+06      0.648500     0.616300              NaN
# 1     9.354948e+03  9.354948e+03      0.644800     0.613100              NaN
# 2     3.271670e+02  3.271670e+02      0.625800     0.597600              NaN
# 3     1.158471e+06  1.158471e+06      0.648200     0.616500              NaN
# 4     1.738325e+04  1.738325e+04    154.690000   150.320000             True
# ..             ...           ...           ...          ...              ...
# 930   2.048240e+01  2.048035e+01      0.000022     0.000020              NaN
# 931   0.000000e+00  0.000000e+00   6423.000000  6254.500000              NaN
# 932   0.000000e+00  0.000000e+00     65.420000    62.220000              NaN
# 933   2.145710e+02  2.145710e+02      0.002806     0.002277              NaN
# 934   4.643071e+02  4.643071e+02      0.000205     0.000175              NaN
#
# [935 rows x 27 columns]

# %%
market_name="DOGE/USD"
path =f"/markets/{market_name}"
url2 =api_url + path
url2
# Out:
# 'https://ftx.com/api/markets/DOGE/USD'

# %%
markets= requests.get(url).json()
data = markets["result"]
df=pd.DataFrame(data)

# %%
df=pd.DataFrame(data)
df["name"]=df["name"].str.replace("-",",")
df["name"]=df["name"].str.replace("/",",")
new2 =df["name"].str.split(",",n=1,expand=True)
df["Nombre"]= new2[0]
df["Divisa"]= new2[1]
df.drop(columns=["name"],inplace=True)

# %%
df.sort_values(by=["price"],ascending=False).head()
# Out:
#      enabled  postOnly  priceIncrement  sizeIncrement  minProvideSize  \
# 161     True     False            0.01       0.000100        0.000100
# 162     True     False            0.10       0.000100        0.000100
# 276     True     False            0.01       0.001000        0.001000
# 159     True     False            5.00       0.000100        0.000100
# 800     True     False            5.00       0.000001        0.000001
#
#            last         bid         ask       price  type  ...  change1h  \
# 161  2764797.44  2762703.57  2768102.01  2764797.44  spot  ... -0.000435
# 162   357570.70   355736.90   356186.60   356186.60  spot  ... -0.000144
# 276   191299.59   190860.35   191397.13   191299.59  spot  ... -0.003526
# 159   102060.00   102135.00   102345.00   102135.00  spot  ...  0.001373
# 800    74455.00    74275.00    74395.00    74395.00  spot  ... -0.001543
#
#     change24h  changeBod quoteVolume24h  volumeUsd24h  priceHigh24h  \
# 161  0.028609   0.026902   1.555145e+08  1.073050e+06    2784557.76
# 162  0.017310   0.016319   2.808187e+05  1.507716e+04     359024.50
# 276  0.040012   0.029773   9.857165e+06  6.801444e+04     193438.01
# 159  0.039119   0.037641   1.195420e+07  2.236392e+06     102695.00
# 800 -0.002815  -0.004616   3.029823e+04  3.029823e+04      76335.00
#
#      priceLow24h  tokenizedEquity    Nombre  Divisa
# 161   2686930.35              NaN       BTC     JPY
# 162    348722.20              NaN       BTC    TRYB
# 276    183785.87              NaN       ETH     JPY
# 159     98290.00              NaN       BTC     BRZ
# 800     73635.00              NaN  DOGEHALF     USD
#
# [5 rows x 28 columns]

# %%
df.sort_values(by=["price"],ascending=False).drop_duplicates().head(20)
# Out:
#      enabled  postOnly  priceIncrement  sizeIncrement  minProvideSize  \
# 161     True     False            0.01       0.000100        0.000100
# 162     True     False            0.10       0.000100        0.000100
# 276     True     False            0.01       0.001000        0.001000
# 159     True     False            5.00       0.000100        0.000100
# 800     True     False            5.00       0.000001        0.000001
# 861     True     False            5.00       0.000001        0.000001
# 774     True     False            2.50       0.000001        0.000001
# 158     True     False            1.00       0.000100        0.000100
# 735     True     False            1.00       0.000010        0.000010
# 814     True     False            1.00       0.000010        0.000010
# 753     True     False            1.00       0.000010        0.000010
# 160     True     False            1.00       0.000100        0.000100
# 820     True     False            1.00       0.000010        0.000010
# 157     True     False            1.00       0.000100        0.000100
# 871     True     False            1.00       0.000010        0.000010
# 155     True     False            1.00       0.000100        0.000100
# 149     True     False            1.00       0.000100        0.000100
# 163     True     False            1.00       0.000100        0.000100
# 164     True     False            1.00       0.000100        0.000100
# 146     True     False            1.00       0.000100        0.001000
#
#            last         bid         ask       price    type  ...  change1h  \
# 161  2764797.44  2762703.57  2768102.01  2764797.44    spot  ... -0.000435
# 162   357570.70   355736.90   356186.60   356186.60    spot  ... -0.000144
# 276   191299.59   190860.35   191397.13   191299.59    spot  ... -0.003526
# 159   102060.00   102135.00   102345.00   102135.00    spot  ...  0.001373
# 800    74455.00    74275.00    74395.00    74395.00    spot  ... -0.001543
# 861    67970.00    67265.00    67460.00    67460.00    spot  ... -0.003324
# 774    37595.00    37517.50    37567.50    37567.50    spot  ... -0.000731
# 158    29630.00    29620.00    29654.00    29630.00    spot  ... -0.002021
# 735    30297.00    29367.00    29440.00    29440.00    spot  ... -0.000306
# 814    23843.00    23635.00    23688.00    23688.00    spot  ...  0.000422
# 753    20080.00    20266.00    20340.00    20266.00    spot  ... -0.006033
# 160    19859.00    19865.00    19875.00    19865.00    spot  ...  0.000101
# 820    19535.00    19499.00    19533.00    19533.00    spot  ... -0.000307
# 157    19200.00    19220.00    19231.00    19220.00  future  ...  0.000260
# 871    19810.00    19141.00    19192.00    19192.00    spot  ... -0.001613
# 155    19159.00    19152.00    19160.00    19159.00  future  ... -0.000052
# 149    19119.00    19116.00    19119.00    19119.00  future  ...  0.000000
# 163    19119.00    19119.00    19120.00    19119.00    spot  ... -0.000052
# 164    19117.00    19115.00    19116.00    19116.00    spot  ... -0.000052
# 146    19111.00    19110.00    19111.00    19111.00  future  ... -0.000209
#
#     change24h  changeBod quoteVolume24h  volumeUsd24h  priceHigh24h  \
# 161  0.028609   0.026902   1.555145e+08  1.073050e+06    2784557.76
# 162  0.017310   0.016319   2.808187e+05  1.507716e+04     359024.50
# 276  0.040012   0.029773   9.857165e+06  6.801444e+04     193438.01
# 159  0.039119   0.037641   1.195420e+07  2.236392e+06     102695.00
# 800 -0.002815  -0.004616   3.029823e+04  3.029823e+04      76335.00
# 861  0.003720   0.005140   0.000000e+00  0.000000e+00      67970.00
# 774  0.002803  -0.000067   0.000000e+00  0.000000e+00      37675.00
# 158  0.030716   0.028819   8.457969e+04  5.455390e+04      29815.00
# 735  0.000306  -0.000204   0.000000e+00  0.000000e+00      30297.00
# 814 -0.001181   0.000845   0.000000e+00  0.000000e+00      23843.00
# 753 -0.001429  -0.002068   0.000000e+00  0.000000e+00      21017.00
# 160  0.026085   0.024709   8.176242e+05  7.836928e+05      19983.00
# 820  0.013438   0.010763   1.873021e+04  1.873021e+04      20715.00
# 157  0.020657   0.017416   1.038994e+07  1.038994e+07      19422.00
# 871  0.011916   0.011223   0.000000e+00  0.000000e+00      19810.00
# 155  0.018283   0.016986   3.200927e+07  3.200927e+07      19390.00
# 149  0.018811   0.018268   4.696157e+07  4.696157e+07      19326.00
# 163  0.018919   0.018214   7.563223e+08  7.563223e+08      19318.00
# 164  0.018651   0.018054   6.105029e+07  6.104826e+07      19316.00
# 146  0.018493   0.017950   2.884198e+09  2.884198e+09      19321.00
#
#      priceLow24h  tokenizedEquity     Nombre  Divisa
# 161   2686930.35              NaN        BTC     JPY
# 162    348722.20              NaN        BTC    TRYB
# 276    183785.87              NaN        ETH     JPY
# 159     98290.00              NaN        BTC     BRZ
# 800     73635.00              NaN   DOGEHALF     USD
# 861     66555.00              NaN  MATICHALF     USD
# 774     37335.00              NaN    BNBHALF     USD
# 158     28743.00              NaN        BTC     AUD
# 735     29196.00              NaN    ADAHALF     USD
# 814     23377.00              NaN    ETCHALF     USD
# 753     20080.00              NaN   ATOMHALF     USD
# 160     19331.00              NaN        BTC     EUR
# 820     19004.00              NaN    ETHHALF     USD
# 157     18778.00              NaN        BTC    0331
# 871     18941.00              NaN    OKBHALF     USD
# 155     18738.00              NaN        BTC    1230
# 149     18692.00              NaN        BTC    0930
# 163     18688.00              NaN        BTC     USD
# 164     18686.00              NaN        BTC    USDT
# 146     18679.00              NaN        BTC    PERP
#
# [20 rows x 28 columns]

# %%
new2 =df2["name"].str.split(",",n=1,expand=True)

# %%
res = requests.get(url2).json()
data2 = markets["result"]
df2=pd.DataFrame(data2)
df2["name"]=df2["name"].str.replace("-",",")
new2 = df2["name"]=df2["name"].str.split("/",n=1,expand=False)

# %%
nondup=df["Nombre"].drop_duplicates()
nondup.head(240)
# Out:
# 0      1INCH
# 4       AAPL
# 7       AAVE
# 12      ABNB
# 15       ACB
#        ...
# 551      RON
# 552     ROOK
# 554     ROSE
# 555      RSR
# 557     RUNE
# Name: Nombre, Length: 240, dtype: object

# %%
Divnodup=df["Divisa"].drop_duplicates()
Divnodup

# %%
ETHUSD.columns.values
# Out:
# array(['enabled', 'postOnly', 'priceIncrement', 'sizeIncrement',
#        'minProvideSize', 'last', 'bid', 'ask', 'price', 'type',
#        'futureType', 'baseCurrency', 'isEtfMarket', 'quoteCurrency',
#        'underlying', 'restricted', 'highLeverageFeeExempt',
#        'largeOrderThreshold', 'change1h', 'change24h', 'changeBod',
#        'quoteVolume24h', 'volumeUsd24h', 'priceHigh24h', 'priceLow24h',
#        'tokenizedEquity', 'Nombre', 'Divisa'], dtype=object)

# %%
import time
import requests
from datetime import datetime
import json
import plotly.graph_objects as go

endpoint_url = "https://ftx.com/api/markets"
base_currency = "DOGE"
quote_currency = "USD"


request_url=f"{endpoint_url}/{base_currency}/{quote_currency}"
all_markets=requests.get(endpoint_url).json()

dh=pd.DataFrame(all_markets["result"])
dh.set_index("name",inplace=True)

#1 dia = 60 *60 *24 segundos



daily = str (60*60*24)
#Fecha inicial = 2022-01-01
start_date = datetime(2022,1,1).timestamp()
#Tomamos el historial del mercado en JSON
historical = requests.get(
    f"{request_url}/candles?resolution={daily}&start_time={start_date}"

).json()

#Convertimos de JSON a Pandas DataFrame
dh=pd.DataFrame(historical["result"])

#Convertimos de time a date
dh["date"] = pd.to_datetime(
    dh["time"]/1000,unit="s",origin="unix"

)
#Removemos columnas innecesarias 
dh.drop(["startTime","time"],axis=1, inplace=True)

# %%
import time
import requests
from datetime import datetime
import json
import plotly.graph_objects as go

# %%
endpoint_url = "https://ftx.com/api/markets"
base_currency = "BTC"
quote_currency = "USD"


request_url=f"{endpoint_url}/{base_currency}/{quote_currency}"

# %%
all_markets=requests.get(endpoint_url).json()

dh=pd.DataFrame(all_markets["result"])
dh.set_index("name",inplace=True)
dh.head(2)

# %%
#1 dia = 60 *60 *24 segundos



daily = str (60*60*24)
#Start date = 2022-01-01
start_date = datetime(2022,1,1).timestamp()
#Get the historical market data as JSON
historical = requests.get(
    f"{request_url}/candles?resolution={daily}&start_time={start_date}"

).json()

#Convert JSON to Pandas DataFrame
dh=pd.DataFrame(historical["result"])

#Convert time to date
dh["date"] = pd.to_datetime(
    dh["time"]/1000,unit="s",origin="unix"

)
#Remove unnecessar columns
dh.drop(["startTime","time"],axis=1, inplace=True)

# %%
dh

# %%
#Create a graph objet
fig=go.Figure()
#Set up the layout
fig.update_layout(
    title={
        "text":f"{base_currency}/{quote_currency}",
        "x" : 0.5,
        "xanchor":"center"
    },
    xaxis_title ="Date",
    yaxis_title = "Price",
    xaxis_rangeslider_visible=False
)

#Add candlestick chart
fig.add_trace(
    go.Candlestick(
        x=dh["date"],
        open=dh["open"],
        high=dh["high"],
        low=dh["low"],
        close=dh["close"]
    )
)


fig.show()

# %%
mask1e =df["Nombre"] =="BNB" 
onlyeth=df[mask1e]
mask2e =onlyeth["Divisa"] =="USD"
ETHUSD=onlyeth[mask2e]
EA=ETHUSD["price"].values
EA
# Out:
# array([280.978])

# %%
import numpy as np

# %%
EA
# Out:
# array([], dtype=float64)

# %%
nba=float(EA)
nba
# Out:
# 7059.0

# %%
print(f"{nba:,.2f}")
# Out:
# 102,135.00

# %%
new2[0]
# Out:
# 0         1INCH
# 1         1INCH
# 2         1INCH
# 3         1INCH
# 4          AAPL
#          ...
# 930     XTZBULL
# 931     XTZHALF
# 932    XTZHEDGE
# 933     ZECBEAR
# 934     ZECBULL
# Name: 0, Length: 935, dtype: object

# %%
new = df2["name"]=df2["name"].str.split("/",n=1,expand=False)
new
# Out:
# 0         [1INCH,PERP]
# 1         [1INCH,0930]
# 2         [1INCH,1230]
# 3         [1INCH, USD]
# 4          [AAPL,0930]
#             ...
# 930    [XTZBULL, USDT]
# 931     [XTZHALF, USD]
# 932    [XTZHEDGE, USD]
# 933     [ZECBEAR, USD]
# 934     [ZECBULL, USD]
# Name: name, Length: 935, dtype: object

# %%
df2["name"]=df2["name"].str.replace("-",",")


df2
# Out:
#              name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 0      1INCH,PERP     True     False    1.000000e-04        1.00000
# 1      1INCH,0930     True     False    1.000000e-04        1.00000
# 2      1INCH,1230     True     False    1.000000e-04        1.00000
# 3       1INCH/USD     True     False    1.000000e-04        1.00000
# 4       AAPL,0930     True     False    1.000000e-02        0.01000
# ..            ...      ...       ...             ...            ...
# 930  XTZBULL/USDT     True     False    1.000000e-08    10000.00000
# 931   XTZHALF/USD     True     False    2.500000e-01        0.00001
# 932  XTZHEDGE/USD     True     False    5.000000e-03        0.00100
# 933   ZECBEAR/USD     True     False    1.000000e-06      100.00000
# 934   ZECBULL/USD     True     False    5.000000e-08     1000.00000
#
#      minProvideSize         last          bid          ask        price  ...  \
# 0           1.00000     0.623000     0.623000     0.623100     0.623000  ...
# 1           1.00000     0.622700     0.617600     0.620100     0.620100  ...
# 2           1.00000     0.611700     0.601700     0.604400     0.604400  ...
# 3           1.00000     0.622900     0.622800     0.623500     0.622900  ...
# 4           0.01000   152.400000   150.500000   151.010000   151.010000  ...
# ..              ...          ...          ...          ...          ...  ...
# 930     10000.00000     0.000021     0.000019     0.000020     0.000020  ...
# 931         0.00001  6423.000000  6221.500000  6263.750000  6263.750000  ...
# 932         0.00100    65.030000    65.110000    65.905000    65.110000  ...
# 933       100.00000     0.002759     0.002635     0.002749     0.002749  ...
# 934      1000.00000     0.000176     0.000175     0.000179     0.000176  ...
#
#     highLeverageFeeExempt largeOrderThreshold  change1h  change24h changeBod  \
# 0                   False               350.0 -0.009854   0.027883  0.040588
# 1                   False               350.0 -0.004815   0.023436  0.037998
# 2                   False               350.0 -0.009830   0.028591  0.044229
# 3                    True               280.0 -0.010642   0.027718  0.040943
# 4                   False               350.0 -0.005794   0.008010  0.006465
# ..                    ...                 ...       ...        ...       ...
# 930                  True               196.0 -0.012658  -0.011696  0.011976
# 931                  True               280.0 -0.002389  -0.001912  0.000599
# 932                  True               280.0  0.001230   0.001230 -0.002528
# 933                  True               280.0  0.003651  -0.096912 -0.108047
# 934                  True               280.0  0.000000   0.107692  0.135135
#
#     quoteVolume24h  volumeUsd24h  priceHigh24h  priceLow24h  tokenizedEquity
# 0     5.066928e+06  5.066928e+06      0.636300     0.589100              NaN
# 1     6.359793e+04  6.359793e+04      0.630200     0.590700              NaN
# 2     7.573323e+02  7.573323e+02      0.613500     0.573100              NaN
# 3     5.131578e+05  5.131578e+05      0.636000     0.590500              NaN
# 4     8.863575e+03  8.863575e+03    154.230000   149.200000             True
# ..             ...           ...           ...          ...              ...
# 930   1.068080e+01  1.068009e+01      0.000022     0.000019              NaN
# 931   0.000000e+00  0.000000e+00   6423.000000  6188.000000              NaN
# 932   0.000000e+00  0.000000e+00     66.770000    65.030000              NaN
# 933   9.486998e+03  9.486998e+03      0.003144     0.002612              NaN
# 934   4.126354e+02  4.126354e+02      0.000182     0.000152              NaN
#
# [935 rows x 27 columns]

# %%
dforder=df.sort_values(by=["price"])
dforder
# Out:
#               name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 888  THETABEAR/USD     True     False    1.000000e-08   1.000000e+08
# 847   LINKBEAR/USD     True     False    1.000000e-08   1.000000e+08
# 848  LINKBEAR/USDT     True     False    1.000000e-08   1.000000e+08
# 883    SXPBEAR/USD     True     False    1.000000e-08   1.000000e+07
# 733    ADABEAR/USD     True     False    1.000000e-08   1.000000e+08
# ..             ...      ...       ...             ...            ...
# 737   ALGOBEAR/USD     True     False    1.000000e-08   1.000000e+12
# 738   ALGOBULL/USD     True     False    1.000000e-08   1.000000e+08
# 751   ATOMBEAR/USD     True     False    1.000000e-08   1.000000e+10
# 770    BNBBEAR/USD     True     False    1.000000e-08   1.000000e+08
# 771   BNBBEAR/USDT     True     False    1.000000e-08   1.000000e+08
#
#      minProvideSize          last           bid           ask         price  \
# 888    1.000000e+08  1.000000e-08  2.000000e-08  1.000000e-08  1.000000e-08
# 847    1.000000e+08  1.000000e-08  1.000000e-08  1.000000e-08  1.000000e-08
# 848    1.000000e+08  1.000000e-08  1.000000e-08  4.000000e-08  1.000000e-08
# 883    1.000000e+07  1.000000e-08  1.000000e-08  5.000000e-08  1.000000e-08
# 733    1.000000e+08  1.000000e-08  1.000000e-08  1.000000e-08  1.000000e-08
# ..              ...           ...           ...           ...           ...
# 737    1.000000e+12  1.000000e-08           NaN           NaN           NaN
# 738    1.000000e+08  1.000000e-08           NaN  1.000000e-08           NaN
# 751    1.000000e+10  1.000000e-08           NaN  2.000000e-08           NaN
# 770    1.000000e+08  1.000000e-08           NaN  1.000000e-08           NaN
# 771    1.000000e+08  1.000000e-08           NaN  2.000000e-08           NaN
#
#      ... highLeverageFeeExempt largeOrderThreshold change1h  change24h  \
# 888  ...                  True               280.0      0.0        0.0
# 847  ...                  True               280.0      0.0        0.0
# 848  ...                  True               196.0      0.0        0.0
# 883  ...                  True               280.0      0.0        0.0
# 733  ...                  True               280.0      0.0        0.0
# ..   ...                   ...                 ...      ...        ...
# 737  ...                  True               280.0      0.0        0.0
# 738  ...                  True               280.0      0.0        0.0
# 751  ...                  True               280.0      0.0        0.0
# 770  ...                  True               280.0      0.0        0.0
# 771  ...                  True               196.0      0.0        0.0
#
#     changeBod quoteVolume24h  volumeUsd24h  priceHigh24h   priceLow24h  \
# 888       0.0            0.0           0.0  1.000000e-08  1.000000e-08
# 847       0.0            0.0           0.0  1.000000e-08  1.000000e-08
# 848       0.0            0.0           0.0  1.000000e-08  1.000000e-08
# 883       0.0            0.0           0.0  1.000000e-08  1.000000e-08
# 733       0.0            0.0           0.0  1.000000e-08  1.000000e-08
# ..        ...            ...           ...           ...           ...
# 737       0.0            0.0           0.0  0.000000e+00  0.000000e+00
# 738       0.0            0.0           0.0  0.000000e+00  0.000000e+00
# 751       0.0            0.0           0.0  0.000000e+00  0.000000e+00
# 770       0.0            0.0           0.0  0.000000e+00  0.000000e+00
# 771       0.0            0.0           0.0  0.000000e+00  0.000000e+00
#
#      tokenizedEquity
# 888              NaN
# 847              NaN
# 848              NaN
# 883              NaN
# 733              NaN
# ..               ...
# 737              NaN
# 738              NaN
# 751              NaN
# 770              NaN
# 771              NaN
#
# [935 rows x 27 columns]

# %%
my_plot = df2.plot("price","change24h",kind="scatter")
plt.show()
